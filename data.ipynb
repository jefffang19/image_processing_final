# %% [markdown]
# <a href="https://colab.research.google.com/github/jefffang19/image_processing_final/blob/main/data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# if use google colab, mount your drive

from google.colab import drive
drive.mount('/content/gdrive')

path = F"/content/gdrive/My Drive/ip_final/"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # The structure of the dataset
#
# ```
# 0 (patient)
#   |
#   | -|- CT => mask
#      |- FT => mask
#      |- MN => mask
#      |- T1 => input image 1
#      |- T2 => input image 2
# ```

# %%
import cv2
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # Patient Number #

# %%
pat = 0

# %% [markdown]
# # CT

# %%
ct_path = path + 'data/dip/{}/CT/0.jpg'.format(pat)

# %%
img = cv2.imread(ct_path)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # FT

# %%
ft_path = path + 'data/dip/{}/FT/0.jpg'.format(pat)

img = cv2.imread(ft_path)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # MN

# %%
mn_path = path + 'data/dip/{}/MN/0.jpg'.format(pat)

img = cv2.imread(mn_path)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # T1|

# %%
t1_path = path + 'data/dip/{}/T1/0.jpg'.format(pat)

img = cv2.imread(t1_path)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # T2

# %%
t2_path = path + 'data/dip/{}/T2/0.jpg'.format(pat)

img = cv2.imread(t2_path)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
